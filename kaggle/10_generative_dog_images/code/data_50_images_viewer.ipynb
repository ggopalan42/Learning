# %%
import numpy as np
from PIL import Image
import cv2
import os
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
PATH = '../input/all-dogs/all-dogs/'
CROPPED_IMAGES_DIR = '../input/cropped_images/images/'

NUM_CROPPED_IMAGES = 500000

# %%
cropped_fn_list = os.listdir(CROPPED_IMAGES_DIR)
original_fn_list = os.listdir(PATH)

# %%
index = 68
resize_32 = (32,32)
resize_64 = (64,64)
# image_full_path = PATH + original_fn_list[index]
image_full_path = CROPPED_IMAGES_DIR + cropped_fn_list[index]
img_orig = cv2.imread(image_full_path)
img_32 = cv2.resize(img_orig, resize_32)
img_64 = cv2.resize(img_orig, resize_64)
plt.imshow(img_orig)
